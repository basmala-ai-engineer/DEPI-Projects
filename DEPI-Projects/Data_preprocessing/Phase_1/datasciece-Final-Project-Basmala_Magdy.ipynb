# %% [markdown]
# <div style="border-radius:10px;
#             border : #015a2c solid;
#             background-color:#D7D9DB;
#            font-size:110%;
#            letter-spacing:0.5px;
#             text-align: center">
# ​
# <center><h1 style="padding: 25px 0px; color:#015a4c; font-weight: bold; font-family: Cursive">
# Amit Project for Data Science Module <br><br>💡💡💡💡💡 <br><br> DEPI_BS_DS_R3  </h1></center>
# <center><h3 style="padding-bottom: 25px; color:#025b2c; font-weight: bold; font-style:italic; font-family: Cursive">
# Using Project: Trip data Ford go bike  </h3></center>
# ​
# </div>

# %% [markdown]
# # Part I - (Dataset Exploration for Ford GoBike)
#
# ### worked by (Basmala Magdy/2026 )
#
# ## Introduction
#
# .
#
# > **Let's introduce our dataset:**
#
#
# ======================================
#
# .
#
# **This data set information was produced from `Ford GoBike` System** the information in it talked about individual rides that were made in a bike-sharing system for covering San Francisco Bay area.**
#
# .

# %% [markdown]
# > ## And here are the main exploring questions
#
#
#
#    **==================================================**
#
#
#
# - What is the structure of your dataset?
#
#
# - What are the main interesting features in the dataset?
#
#
# - What features in the dataset supported my investigation for these interesting features?
#
#
#
#
# .
#
# > ### Also here are the investigative questions classified into three types
#
#
#
#    **================================================**
#
#
#
#
# ###  <a href='#011'> Univariate Exploration</a>
#
# - <a href='#1'> 1 ) . What is the distribution of `User type`?</a>
# - <a href='#2'> 2 ) . What is the distribution for the `bike share users on all Trips`?</a>
# - <a href='#3'> 3 ) . What is the distribution for users' `ages`?</a>
# - <a href='#4'> 4 ) . Do the users' ages have `outlier` values?</a>
# - <a href='#5'> 5 ) . What is the distribution for the trip duration in `minutes`? </a>
# - <a href='#6'> 6) . What is the distribution for `member_gender`? </a>
# - <a href='#7'> 7) . What is the distribution for the trip duration in `Hours`?  </a>
#
#
#
#
# ##  <a href='#111'> Bivariate Exploration</a>
#
#
# - <a href='#8'> 8 ) . What the `average duration` of trip for the categories of `user type`? </a>
# - <a href='#9'> 9 ) . How long is the duration of the trip for `each gender` in `minutes`? </a>
# - <a href='#10'> 10 ) . How long is the duration of the trip for each `user_type` in `minutes`?  </a>
# - <a href='#11'> 11 ) . How the user distribution depending on their `Age` and `user_type` ?</a>
# - <a href='#12'>12 ). How the user distribution depending on their `Age` and `member_gender` ?  </a>
#
#
# ##  <a href='#1111'> Multivariate Exploration</a>
#
#
# - <a href='#13'> 13 ) . What is the Correlation between `each` variable in the dataset?</a>
# - <a href='#14'> 14 ) . What is the Correlation between `specific numeric variables` in the dataset?</a>
# - <a href='#15'> 15 ) . What is the  Correlation between `data_stat` variables in the dataset?</a>
#
#
# ##  <a href='#1100'> Conclusions </a>

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Import Libraries</p>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt

import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('fordgobike-tripdataFor201902.csv')
df.head()
# Out:
#    duration_sec start_time end_time  start_station_id  \
# 0         52185    32:10.1  01:56.0              21.0
# 1         42521    53:21.8  42:03.1              23.0
# 2         61854    13:13.2  24:08.1              86.0
# 3         36490    54:26.0  02:36.8             375.0
# 4          1585    54:18.5  20:44.1               7.0
#
#                                  start_station_name  start_station_latitude  \
# 0  Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                     The Embarcadero at Steuart St               37.791464
# 2                           Market St at Dolores St               37.769305
# 3                           Grove St at Masonic Ave               37.774836
# 4                               Frank H Ogawa Plaza               37.804562
#
#    start_station_longitude  end_station_id  \
# 0              -122.400811            13.0
# 1              -122.391034            81.0
# 2              -122.426826             3.0
# 3              -122.446546            70.0
# 4              -122.271738           222.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 1                            Berry St at 4th St             37.775880
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 3                        Central Ave at Fell St             37.773311
# 4                         10th Ave at E 15th St             37.792714
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 1            -122.393170     2535    Customer                NaN
# 2            -122.404904     5905    Customer             1972.0
# 3            -122.444293     6638  Subscriber             1989.0
# 4            -122.248780     4898  Subscriber             1974.0
#
#   member_gender bike_share_for_all_trip
# 0          Male                      No
# 1           NaN                      No
# 2          Male                      No
# 3         Other                      No
# 4          Male                     Yes

# %%
# here we make overview in high-level for data shape and composition
print("Shape:", df.shape)
df.info()
# Out:
# Shape: (183416, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  object
#  2   end_time                 183416 non-null  object
#  3   start_station_id         183219 non-null  float64
#  4   start_station_name       183219 non-null  object
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183219 non-null  float64
#  8   end_station_name         183219 non-null  object
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  object
#  13  member_birth_year        175151 non-null  float64
#  14  member_gender            175151 non-null  object
#  15  bike_share_for_all_trip  183416 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
## check each var  datatype 
df.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id           float64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id             float64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
## I display 15 rows to understand the content values more 

df.head(15)
# Out:
#     duration_sec start_time end_time  start_station_id  \
# 0          52185    32:10.1  01:56.0              21.0
# 1          42521    53:21.8  42:03.1              23.0
# 2          61854    13:13.2  24:08.1              86.0
# 3          36490    54:26.0  02:36.8             375.0
# 4           1585    54:18.5  20:44.1               7.0
# 5           1793    49:58.6  19:51.8              93.0
# 6           1147    55:35.1  14:42.6             300.0
# 7           1615    41:06.8  08:02.8              10.0
# 8           1570    41:48.8  07:59.7              10.0
# 9           1049    49:47.7  07:17.0              19.0
# 10           458    57:57.2  05:35.4             370.0
# 11           506    56:55.5  05:21.7              44.0
# 12          1176    45:12.7  04:49.2             127.0
# 13           915    49:06.1  04:21.9             252.0
# 14           395    56:26.8  03:01.9             243.0
#
#                                    start_station_name  start_station_latitude  \
# 0    Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                       The Embarcadero at Steuart St               37.791464
# 2                             Market St at Dolores St               37.769305
# 3                             Grove St at Masonic Ave               37.774836
# 4                                 Frank H Ogawa Plaza               37.804562
# 5                        4th St at Mission Bay Blvd S               37.770407
# 6                                Palm St at Willow St               37.317298
# 7                          Washington St at Kearny St               37.795393
# 8                          Washington St at Kearny St               37.795393
# 9                                Post St at Kearny St               37.788975
# 10                                Jones St at Post St               37.787327
# 11  Civic Center/UN Plaza BART Station (Market St ...               37.781074
# 12                             Valencia St at 21st St               37.756708
# 13                       Channing Way at Shattuck Ave               37.865847
# 14                        Bancroft Way at College Ave               37.869360
#
#     start_station_longitude  end_station_id  \
# 0               -122.400811            13.0
# 1               -122.391034            81.0
# 2               -122.426826             3.0
# 3               -122.446546            70.0
# 4               -122.271738           222.0
# 5               -122.391198           323.0
# 6               -121.884995           312.0
# 7               -122.404770           127.0
# 8               -122.404770           127.0
# 9               -122.403452           121.0
# 10              -122.413278            43.0
# 11              -122.411738           343.0
# 12              -122.421025           323.0
# 13              -122.267443           244.0
# 14              -122.254337           252.0
#
#                                      end_station_name  end_station_latitude  \
# 0                      Commercial St at Montgomery St             37.794231
# 1                                  Berry St at 4th St             37.775880
# 2        Powell St BART Station (Market St at 4th St)             37.786375
# 3                              Central Ave at Fell St             37.773311
# 4                               10th Ave at E 15th St             37.792714
# 5                                  Broadway at Kearny             37.798014
# 6                            San Jose Diridon Station             37.329732
# 7                              Valencia St at 21st St             37.756708
# 8                              Valencia St at 21st St             37.756708
# 9                                  Mission Playground             37.759210
# 10  San Francisco Public Library (Grove St at Hyde...             37.778768
# 11                                Bryant St at 2nd St             37.783172
# 12                                 Broadway at Kearny             37.798014
# 13                         Shattuck Ave at Hearst Ave             37.873676
# 14                       Channing Way at Shattuck Ave             37.865847
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 0             -122.402923     4902    Customer             1984.0
# 1             -122.393170     2535    Customer                NaN
# 2             -122.404904     5905    Customer             1972.0
# 3             -122.444293     6638  Subscriber             1989.0
# 4             -122.248780     4898  Subscriber             1974.0
# 5             -122.405950     5200  Subscriber             1959.0
# 6             -121.901782     3803  Subscriber             1983.0
# 7             -122.421025     6329  Subscriber             1989.0
# 8             -122.421025     6548  Subscriber             1988.0
# 9             -122.421339     6488  Subscriber             1992.0
# 10            -122.415929     5318  Subscriber             1996.0
# 11            -122.393572     5848  Subscriber             1993.0
# 12            -122.405950     5328    Customer             1990.0
# 13            -122.268487     5101  Subscriber                NaN
# 14            -122.267443     4786  Subscriber             1988.0
#
#    member_gender bike_share_for_all_trip
# 0           Male                      No
# 1            NaN                      No
# 2           Male                      No
# 3          Other                      No
# 4           Male                     Yes
# 5           Male                      No
# 6         Female                      No
# 7           Male                      No
# 8          Other                      No
# 9           Male                      No
# 10        Female                     Yes
# 11          Male                      No
# 12          Male                      No
# 13           NaN                      No
# 14          Male                      No

# %%
# descriptive statistics for numeric variables
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183416.000000     183219.000000           183416.000000
# mean      726.067311        138.590365               37.771221
# std      1794.371831        111.778938                0.099586
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183416.000000   183219.000000         183416.000000
# mean               -122.352661      136.249401             37.771425
# std                   0.117100      111.514916              0.099494
# min                -122.453705        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183416.000000  183416.000000      175151.000000
# mean             -122.352247    4472.890260        1984.806504
# std                 0.116677    1664.386068          10.116589
# min              -122.453705      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %% [markdown]
# > ### What is the structure of your dataset?
#
#
#
#
#
# - The structure of the dataset contains  16 columns and 183416 rows.
#
#
# - Most variables are numeric and categorical in nature , and here are **dtypes summary :**
#
#         - float64 (7)
#         - int64 (2)
#         - object (7)
#
#
#
#
# > ### What are the main interesting features in the dataset?
#
#
#
#
#  **We got three main feature areas which are :**
#
#
#
#
# - Trip duration (duration_sec)
#
#
#
# - User type (Subscriber / Customer)
#
#
#
#
# - Member age and gender
#
#
#
#
# > ### What features in the dataset supported my investigation for these interesting features?
#
#
#
# - Start and end times (start_time, end_time)
#
#
#
# - Member birth year for age calculation
#
#
#
# - Bike sharing indeicator (bike_share_for_all_trip)

# %% [markdown]
# ##  More Exploring ideas to begin my investigation

# %%
#This code for describing statistical data ideas in a more organized and readable table

df.describe(include='all')
# Out:
#          duration_sec start_time end_time  start_station_id  \
# count   183416.000000     183416   183416     183219.000000
# unique            NaN      35783    35767               NaN
# top               NaN    33:48.5  22:24.4               NaN
# freq              NaN         16       20               NaN
# mean       726.067311        NaN      NaN        138.590365
# std       1794.371831        NaN      NaN        111.778938
# min         61.000000        NaN      NaN          3.000000
# 25%        325.000000        NaN      NaN         47.000000
# 50%        514.000000        NaN      NaN        104.000000
# 75%        796.000000        NaN      NaN        239.000000
# max      85444.000000        NaN      NaN        398.000000
#
#           start_station_name  start_station_latitude  start_station_longitude  \
# count                 183219           183416.000000            183416.000000
# unique                   329                     NaN                      NaN
# top     Market St at 10th St                     NaN                      NaN
# freq                    3904                     NaN                      NaN
# mean                     NaN               37.771221              -122.352661
# std                      NaN                0.099586                 0.117100
# min                      NaN               37.317298              -122.453705
# 25%                      NaN               37.770083              -122.412408
# 50%                      NaN               37.780760              -122.398285
# 75%                      NaN               37.797280              -122.286533
# max                      NaN               37.880222              -121.874119
#
#         end_station_id                                   end_station_name  \
# count    183219.000000                                             183219
# unique             NaN                                                329
# top                NaN  San Francisco Caltrain Station 2  (Townsend St...
# freq               NaN                                               4857
# mean        136.249401                                                NaN
# std         111.514916                                                NaN
# min           3.000000                                                NaN
# 25%          44.000000                                                NaN
# 50%         100.000000                                                NaN
# 75%         235.000000                                                NaN
# max         398.000000                                                NaN
#
#         end_station_latitude  end_station_longitude        bike_id  \
# count          183416.000000          183416.000000  183416.000000
# unique                   NaN                    NaN            NaN
# top                      NaN                    NaN            NaN
# freq                     NaN                    NaN            NaN
# mean               37.771425            -122.352247    4472.890260
# std                 0.099494               0.116677    1664.386068
# min                37.317298            -122.453705      11.000000
# 25%                37.770407            -122.411726    3777.000000
# 50%                37.781010            -122.398279    4958.000000
# 75%                37.797320            -122.288045    5502.000000
# max                37.880222            -121.874119    6645.000000
#
#          user_type  member_birth_year member_gender bike_share_for_all_trip
# count       183416      175151.000000        175151                  183416
# unique           2                NaN             3                       2
# top     Subscriber                NaN          Male                      No
# freq        163548                NaN        130655                  166056
# mean           NaN        1984.806504           NaN                     NaN
# std            NaN          10.116589           NaN                     NaN
# min            NaN        1878.000000           NaN                     NaN
# 25%            NaN        1980.000000           NaN                     NaN
# 50%            NaN        1987.000000           NaN                     NaN
# 75%            NaN        1992.000000           NaN                     NaN
# max            NaN        2001.000000           NaN                     NaN

# %%
# display the information about each column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  object
#  2   end_time                 183416 non-null  object
#  3   start_station_id         183219 non-null  float64
#  4   start_station_name       183219 non-null  object
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183219 non-null  float64
#  8   end_station_name         183219 non-null  object
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  object
#  13  member_birth_year        175151 non-null  float64
#  14  member_gender            175151 non-null  object
#  15  bike_share_for_all_trip  183416 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %% [markdown]
# ## <mark>The above result show some missing values exist in some columns So let's display them </mark>

# %%
#yOUR CODES
df.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %% [markdown]
# > ## <mark>The result above shows many missing data </mark>
#
#
#
# ###  To fix this issue You will fill these values with ........... for numeric and ......for categorical

# %%
# trying to fill missing values in my datset using for loop 

for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        df[col].fillna(df[col].mean(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\kh\AppData\Local\Temp\ipykernel_56868\411861979.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# C:\Users\kh\AppData\Local\Temp\ipykernel_56868\411861979.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
#check the Nulls 
df.isnull().sum()
# Out:
# duration_sec               0
# start_time                 0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# bike_id                    0
# user_type                  0
# member_birth_year          0
# member_gender              0
# bike_share_for_all_trip    0
# dtype: int64

# %% [markdown]
# ### **And with a proper category for other (member gender)**

# %%
##  still got a missing value in the member_gender, so let's explore this column more 

# print(gbf.member_gender.head(15))
print(df['member_gender'].head(15))
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3      Other
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8      Other
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: object

# %%
# fill  dataset with missing values.
df['member_gender'].fillna('Other', inplace=True)

# %%
# print(gbf.member_gender.head(15))
print(df['member_gender'].head(15))
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3      Other
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8      Other
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: object

# %%
## check my result above 
df.isnull().sum()
# Out:
# duration_sec               0
# start_time                 0
# end_time                   0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# bike_id                    0
# user_type                  0
# member_birth_year          0
# member_gender              0
# bike_share_for_all_trip    0
# dtype: int64

# %% [markdown]
# > ## <mark>The result above shows that we deal with all missing data </mark>

# %% [markdown]
# ### Now let's check duplicate value

# %%
##  check duplicate in dataset
df.duplicated().sum()
# Out:
# np.int64(4)

# %% [markdown]
# > ##If Not significant duplicated , so won't clean it
#
#
# ### Now let's check the category columns to make more cleaning dataset

# %%
### check the category columns that included object
df.select_dtypes(include=['object']).columns
# Out:
# Index(['start_time', 'end_time', 'start_station_name', 'end_station_name',
#        'user_type', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %% [markdown]
#  > ## From all previous results above I found  :
#
#
#
#  **=========================================================**
#
#
#
# > 1 ) **unique Value** as in ((`member_gender`)) : Not significant , so won't clean it
#
#
#
# > 2 ) **Incorrect data type** as in (( `user_type` &&	`member_gender`)) :  significant change , so I need to clean it.
#
#
# > 3 ) **Good factor** for marketing work as in ((`member_birth_year`)) : so I need to clean it.

# %%
##  step  2 ) Incorrect data type as in (( `user_type` &&	`member_gender`)) :  significant change , so  need to clean it.
df['user_type'] = df['user_type'].astype('category')
df['member_gender'] = df['member_gender'].astype('category')

# %%
## check your work 
df[['user_type', 'member_gender']].dtypes
# Out:
# user_type        category
# member_gender    category
# dtype: object

# %%
## step 3 ) Good factor for marketing work as in ((`member_birth_year`)) : so need to clean it.
## To know the target audience's age and serve on them

# create a column for users' age depending on the current year
df['member_age'] = 2019 - df['member_birth_year']

# %%
## check your work 
df['member_age'].head()
# Out:
# 0    35.000000
# 1    34.193496
# 2    47.000000
# 3    30.000000
# 4    45.000000
# Name: member_age, dtype: float64

# %%
## change the new column age data type from float to int
df['member_age'] = df['member_age'].astype(int)

# %%
## create a function to know the average users ages
def get_avg_age(df):
    return df['member_age'].mean()

print("Average Age:", get_avg_age(df))
# Out:
# Average Age: 34.18477668251407

# %%
## another important factor to offer  marketing services is the trip duration time 

## need to change the time from second to minute to be more usable

df['duration_min'] = df['duration_sec'] / 60

# %%
## I need to change the time from second to Houre  to be more usable
df['duration_hour'] = df['duration_sec'] / 3600

# %%
## check your work 
df[['duration_sec', 'duration_min', 'duration_hour']].head()
# Out:
#    duration_sec  duration_min  duration_hour
# 0         52185    869.750000      14.495833
# 1         42521    708.683333      11.811389
# 2         61854   1030.900000      17.181667
# 3         36490    608.166667      10.136111
# 4          1585     26.416667       0.440278

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Univariate Exploration</p>
# # <a id="011"> Univariate Exploration</a>
#
#
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %% [markdown]
# # <a id="1"> 1 ) . What is the distribution for User type?</a>

# %%
## I will import seaborn library to support me in making visualizations 

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5), dpi=200)
sns.countplot(data=df, x='user_type')
plt.xlabel('User distribution')
plt.ylabel('Frequency')
plt.title('Represent the user distribution depending on user type')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The majority of users are Subscribers rather than regular Customers, indicating that a large portion of the service usage relies on recurring, loyal users.

# %% [markdown]
# # <a id="2"> 2 ) What is the distribution for the bike share users on all Trips?</a>

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Most trips did not participate in the bike share for all trips program, showing that the standard individual booking is much more common.

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.countplot(data=df, x='bike_share_for_all_trip')
plt.xlabel('Bike Share Distribution')
plt.ylabel('Frequency')
plt.title('Represent the distribution for bike share users on all trips')
plt.show()

# %% [markdown]
# # <a id="3"> 3 ) What is the distribution for users' ages? </a>

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.histplot(data=df, x='member_age', bins=30, kde=True)
plt.xlabel('Member Age')
plt.ylabel('Frequency')
plt.title('Distribution of Users Ages')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The user age distribution is right-skewed, with the majority of riders concentrated in their 20s to 40s, representing the active working-age demographic.

# %% [markdown]
# # <a id="4">  4 ) . Do the users' ages have outlier values?</a>

# %%
plt.figure(figsize=(10, 3), dpi=200)
sns.boxplot(data=df, x='member_age')
plt.xlabel('Member Age')
plt.title('Box Plot for Users Ages to Detect Outliers')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Yes, there are some extreme outlier values in the users' ages (such as ages over 100 years old resulting from very old birth years), which stretch the distribution tail

# %% [markdown]
# # <a id="5">  5 ) . What is the distribution for the trip duration in minutes? </a>

# %%
## Review the statistic for trip duration in minutes
df['duration_min'].describe()
# Out:
# count    183416.000000
# mean         12.101122
# std          29.906197
# min           1.016667
# 25%           5.416667
# 50%           8.566667
# 75%          13.266667
# max        1424.066667
# Name: duration_min, dtype: float64

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)
sns.histplot(data=df, x='duration_min', bins=50, kde=True)
plt.xlim(0, 100)
plt.xlabel('Duration (Minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Trip Duration in Minutes')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# .The trip duration distribution is heavily right-skewed, with the vast majority of trips lasting under 20 to 30 minutes, while a few trips extend to much longer durations.

# %% [markdown]
# # <a id="6"> 6 ) . What is the distribution for member_gender?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(8, 4), dpi=200)
sns.countplot(data=df, x='member_gender', order=df['member_gender'].value_counts().index)
plt.xlabel('Member Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Member Gender')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The majority of members identify as male, followed by female, while a small fraction belongs to other categories.

# %% [markdown]
# # <a id="7">    7 )  . What is the distribution for the trip duration in Hours?  </a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)
sns.histplot(data=df, x='duration_hour', bins=50, kde=True)
plt.xlim(0, 2)
plt.xlabel('Duration (Hours)')
plt.ylabel('Frequency')
plt.title('Distribution of Trip Duration in Hours')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Most trips are very short when measured in hours, concentrated heavily in the fraction of an hour (under 30-40 minutes), which aligns with typical bike-sharing commuter behaviors.

# %% [markdown]
# ### The variables distribution:
#
#
# > The distribution of duration present that most of the trips were less than 30 minutes ( we can notice that from the minutes and the hour charts )
#
#
# > And the Age distribution is ( left Skewed ) as most users age are  22 - 39
#
#
# > Most users are subscribers, not Customers and  Males as shown in the charts above.
#
#
#
# ### Were there any interesting and outliers
#
#
# - We got Age outliers for for more than 100 .
#
#
#
# - The distribution of duration was strange where the minutes and the hour charts were 30 minutes or less.

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Bivariate Exploration</p>
# # <a id="111"> Bivariate Exploration</a>
#
# Now let's investigate relationships between pairs of variables in our data.

# %% [markdown]
# # <a id="8"> 8) . What the average duration of trip for the categories of user type?</a>

# %%
# Distribution of Age by user types
plt.figure(figsize=(10, 5), dpi=200)
sns.barplot(data=df, x='user_type', y='duration_min', estimator=lambda x: sum(x) / len(x))
plt.xlabel('User Type')
plt.ylabel('Average Duration (Minutes)')
plt.title('Average Trip Duration by User Type')
plt.show()

# %% [markdown]
# # Make visualization to easy get insight

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Customers tend to have a higher average trip duration compared to Subscribers, even though Subscribers make up the majority of total trips.

# %% [markdown]
# # <a id="9">    9 ) . How long is the duration of the trip for each gender in minutes?  </a>

# %%
# Make visualization to easy get insight

# ------------------------Duration distribution by member gender
plt.figure(figsize=(10, 5), dpi=200)
sns.boxplot(data=df, x='member_gender', y='duration_min', order=df['member_gender'].value_counts().index)
plt.ylim(0, 100)
plt.xlabel('Member Gender')
plt.ylabel('Duration (Minutes)')
plt.title('Trip Duration Distribution by Member Gender')
plt.show()

# %% [markdown]
# # Make visualization to easy get insight

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Trip durations across different genders show similar median values and ranges, indicating that gender does not drastically change the length of the bike trips.

# %% [markdown]
# # <a id="10 "> 10 ) . How long is the duration of the trip for each user_type in minutes?  </a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)
sns.boxplot(data=df, x='user_type', y='duration_min')
plt.ylim(0, 100)
plt.xlabel('User Type')
plt.ylabel('Duration (Minutes)')
plt.title('Trip Duration Distribution by User Type')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Customers exhibit a wider spread and higher median trip durations compared to Subscribers, showing that regular customers tend to take longer leisure rides.

# %% [markdown]
# # <a id="11">  11 ) . How the user distribution depending on their Age and user_type ? </a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)
sns.boxplot(data=df, x='user_type', y='member_age')
plt.ylim(15, 80)
plt.xlabel('User Type')
plt.ylabel('Member Age')
plt.title('Age Distribution by User Type')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# Both Subscribers and Customers share very similar age distributions, with the median age hovering around the 30s across both user categories.

# %% [markdown]
# #  <a id="12"> 12 ). How the user distribution depending on their Age and member_gender ?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(10, 5), dpi=200)
sns.boxplot(data=df, x='member_gender', y='member_age', order=df['member_gender'].value_counts().index)
plt.ylim(15, 80)
plt.xlabel('Member Gender')
plt.ylabel('Member Age')
plt.title('Age Distribution by Member Gender')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
# The age distribution remains consistent across different gender categories, showing no significant variation in age medians among males, females, or other groups.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# Customers typically exhibited longer trip durations compared to subscribers, whereas age and gender distributions remained largely consistent across different user types and groups.
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# The core relationships show that trip duration is more heavily influenced by the user type rather than demographic factors like age or gender.

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Multivariate Exploration</p>
# # <a id="1111"> Multivariate Exploration </a>
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
## check your work 
numeric_df = df.select_dtypes(include=['float64', 'int64'])
print(numeric_df.corr())
# Out:
#                          duration_sec  start_station_id  \
# duration_sec                 1.000000         -0.008651
# start_station_id            -0.008651          1.000000
# start_station_latitude       0.010519         -0.189614
# start_station_longitude     -0.037935          0.456149
# end_station_id               0.003062          0.336240
# end_station_latitude         0.010880         -0.178480
# end_station_longitude       -0.038912          0.463664
# bike_id                     -0.006130         -0.064666
# member_birth_year           -0.005390          0.112319
# member_age                   0.005162         -0.112249
# duration_min                 1.000000         -0.008651
# duration_hour                1.000000         -0.008651
#
#                          start_station_latitude  start_station_longitude  \
# duration_sec                           0.010519                -0.037935
# start_station_id                      -0.189614                 0.456149
# start_station_latitude                 1.000000                -0.677254
# start_station_longitude               -0.677254                 1.000000
# end_station_id                        -0.178445                 0.476532
# end_station_latitude                   0.989970                -0.681840
# end_station_longitude                 -0.682663                 0.992410
# bike_id                                0.050001                -0.141779
# member_birth_year                     -0.075213                 0.124155
# member_age                             0.075136                -0.123937
# duration_min                           0.010519                -0.037935
# duration_hour                          0.010519                -0.037935
#
#                          end_station_id  end_station_latitude  \
# duration_sec                   0.003062              0.010880
# start_station_id               0.336240             -0.178480
# start_station_latitude        -0.178445              0.989970
# start_station_longitude        0.476532             -0.681840
# end_station_id                 1.000000             -0.196568
# end_station_latitude          -0.196568              1.000000
# end_station_longitude          0.465921             -0.684222
# bike_id                       -0.054598              0.049249
# member_birth_year              0.109923             -0.075313
# member_age                    -0.109862              0.075234
# duration_min                   0.003062              0.010880
# duration_hour                  0.003062              0.010880
#
#                          end_station_longitude   bike_id  member_birth_year  \
# duration_sec                         -0.038912 -0.006130          -0.005390
# start_station_id                      0.463664 -0.064666           0.112319
# start_station_latitude               -0.682663  0.050001          -0.075213
# start_station_longitude               0.992410 -0.141779           0.124155
# end_station_id                        0.465921 -0.054598           0.109923
# end_station_latitude                 -0.684222  0.049249          -0.075313
# end_station_longitude                 1.000000 -0.143522           0.124969
# bike_id                              -0.143522  1.000000           0.035186
# member_birth_year                     0.124969  0.035186           1.000000
# member_age                           -0.124748 -0.035081          -0.999992
# duration_min                         -0.038912 -0.006130          -0.005390
# duration_hour                        -0.038912 -0.006130          -0.005390
#
#                          member_age  duration_min  duration_hour
# duration_sec               0.005162      1.000000       1.000000
# start_station_id          -0.112249     -0.008651      -0.008651
# start_station_latitude     0.075136      0.010519       0.010519
# start_station_longitude   -0.123937     -0.037935      -0.037935
# end_station_id            -0.109862      0.003062       0.003062
# end_station_latitude       0.075234      0.010880       0.010880
# end_station_longitude     -0.124748     -0.038912      -0.038912
# bike_id                   -0.035081     -0.006130      -0.006130
# member_birth_year         -0.999992     -0.005390      -0.005390
# member_age                 1.000000      0.005162       0.005162
# duration_min               0.005162      1.000000       1.000000
# duration_hour              0.005162      1.000000       1.000000

# %% [markdown]
# # <a id="13">  13 ) . What is the  Correlation between each variable in the dataset?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(8, 6), dpi=200)
numeric_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes/hours`)
# -The correlation matrix shows that trip duration variables are strongly related to each other because they measure the same thing in different units.
#
# -Member age doesn't have a clear linear relationship with the trip duration.

# %% [markdown]
# # <a id="14"> 14 )  .  What is the  Correlation between `specific numeric variables` in the dataset?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(8, 6), dpi=200)
specific_vars = df[['member_age', 'duration_min', 'bike_id']]
sns.heatmap(specific_vars.corr(), annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
plt.title('Correlation between Specific Numeric Variables')
plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# - The heatmap shows a negative correlation between member age and birth year, which makes total sense.
#
#
#
#
# - Other variables like bike ID and age don't show any real correlation.

# %% [markdown]
# # <a id="15">  15 ) What is the  Correlation between data_stat variables in the dataset?</a>

# %%
"""""This time I will use heatmap  to explain how Correlation between data_stat variables

in the dataset in more clear and specific percentage"""

# Make visualization to easy get insight
plt.figure(figsize=(8, 6), dpi=200)
sns.heatmap(df[['member_age', 'duration_min']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Final Statistical Correlation Summary')
plt.show()

# %% [markdown]
# > ### <mark>The above charts show how Correlation between specific numeric variables in the dataset using heatmap plots  </mark>
#
#
#
# **Actually the `heat map`  display the above ideas in clear percentages**
#
#
#
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# - There is a `negative  Correlation` between  member_birth_year  and age which normal.
#
#
#
#
# - There is `no significant Correlation` for any variable with `bike_id `

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Conclusions</p>
# # <a id="1100"> Conclusions </a>
#
# #example
# - Most users were Male and fell within the active working age group.
#
#
# - Subscribers made up the vast majority of rides with shorter, consistent durations.
#
# - Customers took fewer trips, but their trip durations were significantly longer on average.
#
# -
#
#
#
# ## limitation
# example
# - We encountered missing values in some demographic columns, which we handled during data cleaning.
#
# - The dataset represents a limited timeframe (February 2019), so findings might not generalize to all seasons of the year.
